# %%
# import torch
# import sys
# print(sys.executable)
# import torch.nn as nn
# import torch.optim as optim
# a=1
# a

# %%
import torch
print(torch.__version__)
# Out:
# 2.12.0+cpu

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Acer\anaconda3\python.exe

# %%
import torch.nn as nn
import torch.optim as optim

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.Linear = nn.Linear(1,1)
    def forward(self, x):
        return self.Linear(x)
        
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

model = MyModel()

# loss function
loss_fn = nn.MSELoss()
# optimiser
optimiser = optim.Adam(model.parameters(), lr = 0.1 )

# train loop 
for epoch in range(10):
    optimiser.zero_grad()
    y_pred = model(x)
    loss = loss_fn(y_pred, y)
    loss.backward()
    optimiser.step()
    print(f" Epoch {epoch+1}: Loss = {loss.item():.4f} ")
# Out:
#  Epoch 1: Loss = 51.5093
#  Epoch 2: Loss = 46.4019
#  Epoch 3: Loss = 41.5726
#  Epoch 4: Loss = 37.0257
#  Epoch 5: Loss = 32.7647
#  Epoch 6: Loss = 28.7919
#  Epoch 7: Loss = 25.1085
#  Epoch 8: Loss = 21.7144
#  Epoch 9: Loss = 18.6083
#  Epoch 10: Loss = 15.7870

# %% [markdown]
# Saving Model

# %%
torch.save(model.state_dict(), "linear_model.pth")
